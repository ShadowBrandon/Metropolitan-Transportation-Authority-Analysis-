# %%
import pandas as pd
import urllib.parse as ul
import urllib.request
import json

# %%
#MTA Turnstile data from week of April 30, 2016
url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_180630.txt'
turnstiles = pd.read_csv(url, usecols=['STATION'], header = 0)

#url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_160430.txt'
#turnstiles = pd.read_csv(url, usecols=['STATION'], header = 0)

# %%
mta_stations = list(turnstiles['STATION'].unique())
mta_stations
# Out:
# ['59 ST',
#  '5 AV/59 ST',
#  '57 ST-7 AV',
#  '49 ST',
#  'TIMES SQ-42 ST',
#  '34 ST-HERALD SQ',
#  '28 ST',
#  '23 ST',
#  '14 ST-UNION SQ',
#  '8 ST-NYU',
#  'PRINCE ST',
#  'CANAL ST',
#  'CITY HALL',
#  'CORTLANDT ST',
#  'RECTOR ST',
#  'WHITEHALL S-FRY',
#  'DELANCEY/ESSEX',
#  'BOWERY',
#  'CHAMBERS ST',
#  'FULTON ST',
#  'BROAD ST',
#  '7 AV',
#  'PARK PLACE',
#  'BOTANIC GARDEN',
#  'PROSPECT PARK',
#  'PARKSIDE AV',
#  'CHURCH AV',
#  'BEVERLEY ROAD',
#  'CORTELYOU RD',
#  'NEWKIRK PLAZA',
#  'AVENUE H',
#  'AVENUE J',
#  'AVENUE M',
#  'KINGS HWY',
#  'AVENUE U',
#  'NECK RD',
#  'SHEEPSHEAD BAY',
#  'BRIGHTON BEACH',
#  'OCEAN PKWY',
#  'BOROUGH HALL',
#  'JAY ST-METROTEC',
#  'DEKALB AV',
#  'ATL AV-BARCLAY',
#  'UNION ST',
#  '4AV-9 ST',
#  'PROSPECT AV',
#  '25 ST',
#  '36 ST',
#  '45 ST',
#  '53 ST',
#  'BAY RIDGE AV',
#  '77 ST',
#  '86 ST',
#  'BAY RIDGE-95 ST',
#  '8 AV',
#  'FT HAMILTON PKY',
#  'NEW UTRECHT AV',
#  '18 AV',
#  '20 AV',
#  'BAY PKWY',
# ...

# %%
stations_zip = pd.DataFrame(columns = ['STATION', 'ZIP'])
stations_zip.head(2)
# Out:
# Empty DataFrame
# Columns: [STATION, ZIP]
# Index: []

# %%
zips = pd.DataFrame(data=None)
#gmaps_base_url = 'https://maps.googleapis.com/maps/api/geocode/json?address='
gmaps_base_url = 'https://maps.googleapis.com/maps/api/geocode/json?address='
api_key = 'AIzaSyAB_325CQ2YDOMnNaeq6J5ubuacFIHq8hs'
scontext = None




#zips = pd.DataFrame(data=None)
#gmaps_base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
#api_key = 'AIzaSyBUIDQg5zs2VfotIlrkwsfUjPburQuSbD4'
#scontext = None

# %%
#WHY DOES GMAPS_BASE_URL + UL.URLENCODE(SEARCH_CRITERIA FAIL)?

for station in mta_stations:
    search_criteria = {'address': station + ' station, New York, NY','key' : api_key}
    url = gmaps_base_url + ul.urlencode(search_criteria)
    print(url)
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=address=59+ST+station%2C+New+York%2C+NY&key=AIzaSyAB_325CQ2YDOMnNaeq6J5ubuacFIHq8hs
# https://maps.googleapis.com/maps/api/geocode/json?address=address=5+AV%2F59+ST+station%2C+New+York%2C+NY&key=AIzaSyAB_325CQ2YDOMnNaeq6J5ubuacFIHq8hs
# https://maps.googleapis.com/maps/api/geocode/json?address=address=57+ST-7+AV+station%2C+New+York%2C+NY&key=AIzaSyAB_325CQ2YDOMnNaeq6J5ubuacFIHq8hs
# https://maps.googleapis.com/maps/api/geocode/json?address=address=49+ST+station%2C+New+York%2C+NY&key=AIzaSyAB_325CQ2YDOMnNaeq6J5ubuacFIHq8hs
# https://maps.googleapis.com/maps/api/geocode/json?address=address=TIMES+SQ-42+ST+station%2C+New+York%2C+NY&key=AIzaSyAB_325CQ2YDOMnNaeq6J5ubuacFIHq8hs
# https://maps.googleapis.com/maps/api/geocode/json?address=address=34+ST-HERALD+SQ+station%2C+New+York%2C+NY&key=AIzaSyAB_325CQ2YDOMnNaeq6J5ubuacFIHq8hs
# ...

# %%
ul.urlencode(search_criteria)
# Out:
# 'address=RIT-ROOSEVELT+station%2C+New+York%2C+NY&key=AIzaSyAB_325CQ2YDOMnNaeq6J5ubuacFIHq8hs'

# %%
gmaps_base_url
# Out:
# 'https://maps.googleapis.com/maps/api/geocode/json?address='

# %%
# Out:
# 'https://maps.googleapis.com/maps/api/geocode/json?address='

# %%
#https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway,+Mountain+View,+CA&key=AIzaSyAB_325CQ2YDOMnNaeq6J5ubuacFIHq8hs
#
zips=[]
for station in mta_stations:
    search_criteria = {'address': station + ' station, New York, NY','key' : api_key}
    url = gmaps_base_url + ul.urlencode(search_criteria) #Basically urllib provides urlencode method which is used for fetching urls. Can make changes while fetching the url via urllib. 
    uh = urllib.request.urlopen(url) #data = urllib.urlopen(url)
    data = uh.read() 
    js = json.loads(data)
    zip_code = js['results'][0]['address_components'][-1]["long_name"] #We need the last one from the dictionary
    #zip_dict = (item for item in dicts if item["types"] == [ "postal_code" ]).next()
    #zip_code = zip_dict['long_name']
    zips.append((station, zip_code))
    print(zip_code)
print(zips)
# Out:
# New York
# 10022
# 10106
# 10020
# 10018
# New York
# 10001
# 10011
# United States
# 10003
# 3209
# 10013
# 10007
# 10006
# 10006
# 10004
# 10002
# 2811
# 10007
# 10038
# 10005
# 10019
# 10007
# 10458
# 11226
# 11226
# 11218
# 11226
# 11226
# 11226
# 11230
# 11230
# 11230
# 11229
# 11229
# 11229
# 11235
# 11235
# 11235
# 11201
# 11201
# 11217
# 11217
# 11215
# 11215
# 11215
# 11232
# 10012
# 11220
# 10022
# 11220
# 10075
# 10028
# 11209
# 11220
# 11219
# 11219
# 11204
# 11204
# 11204
# 11219
# 10019
# 11219
# 11375
# 10024
# 11214
# 11214
# United States
# 11224
# United States
# 10003
# 10040
# 11211
# 11211
# 11211
# 10017
# 11206
# 11237
# 11237
# 11237
# 11207
# 11207
# 11207
# United States
# United States
# 11212
# United States
# 11236
# 11236
# New York
# 11435
# 11211
# 11211
# 11206
# 11237
# 11221
# 11221
# 11207
# 11207
# 11207
# 11208
# 11208
# 11208
# 11208
# 11421
# 11421
# 11373
# 11417
# 11418
# 10314
# 11221
# 11237
# 11385
# 11385
# 11385
# 11379
# 10034
# 10040
# ...

# %%
for station in zips:
    try:
        int(station[1])
    except:
        print(station)
# Out:
# ('59 ST', 'New York')
# ('34 ST-HERALD SQ', 'New York')
# ('14 ST-UNION SQ', 'United States')
# ('CONEY IS-STILLW', 'United States')
# ('6 AV', 'United States')
# ('ATLANTIC AV', 'United States')
# ('SUTTER AV', 'United States')
# ('NEW LOTS', 'United States')
# ('HOWARD BCH JFK', 'New York')
# ('59 ST COLUMBUS', 'New York')
# ('14 ST', 'United States')
# ('HOYT-SCHER', 'United States')
# ('BROADWAY JCT', 'New York')
# ('JKSN HT-ROOSVLT', 'United States')
# ('KEW GARDENS', 'United States')
# ('JAMAICA CENTER', 'New York')
# ('NEWARK HW BMEBE', 'United States')
# ('TWENTY THIRD ST', 'New York')
# ('NEWARK BM BW', 'United States')
# ('82 ST-JACKSON H', 'New York')
# ('SUTTER AV-RUTLD', 'United States')
# ('NEW LOTS AV', 'New York')
# ('RIT-MANHATTAN', 'United States')

# %%
errors = {'CONEY IS-STILLW' : 11224,
          'JFK JAMAICA CT1' : 11435,
          'HOYT-SCHER' : 11201,
          'AQUEDUCT N.COND' : 11417,
          'KEW GARDENS' : 11415,
          'NEWARK BM BW' : '07102',
          'JAMAICA VAN WK' : 11418,
          'MORISN AV/SNDVW' : 10472,
}

for station, zip_code in errors.iteritems():
    zips = zips.append(pd.Series((station, zip_code)), ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-2822ec5cc59b> in <module>()
#       9 }
#      10
# ---> 11 for station, zip_code in errors.iteritems():
#      12     zips = zips.append(pd.Series((station, zip_code)), ignore_index=True)
#
# AttributeError: 'dict' object has no attribute 'iteritems'

# %%
zips.rename(columns = {0: 'station', 1: 'zip_code'},
          inplace= True)
zips.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-e237aab789cc> in <module>()
# ----> 1 zips.rename(columns = {0: 'station', 1: 'zip_code'},
#       2           inplace= True)
#       3 zips.head()
#
# AttributeError: 'list' object has no attribute 'rename'

# %%
zips.to_csv('zips.csv', index= False) #Write to csv

# %%
zips.head()
